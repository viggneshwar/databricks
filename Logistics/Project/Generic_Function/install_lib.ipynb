# %%
# %pip install word2number

from word2number import w2n

# Example conversions
print(w2n.word_to_num("twenty five"))   # 25
print(w2n.word_to_num("one hundred"))   # 100
print(w2n.word_to_num("ten thousand"))  # 10000
