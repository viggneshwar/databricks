# %%
# %sql
CREATE CONNECTION mysql_connectionworking2
TYPE mysql
OPTIONS (
  host '34.63.107.222.bc.googleusercontent.com',
  port '3306',
  user 'we47user',
  password 'We47@123',
  trustServerCertificate 'true'
);

CREATE FOREIGN CATALOG cloudsql_foreign_catalog2
USING CONNECTION mysql_connectionworking2;

# %%
# %sql
select * from cloudsql_foreign_catalog2.testdb.tbl1;

# %%
# %sql
CREATE CONNECTION gcp_mysql_conn_wd36
TYPE mysql
OPTIONS (
  host '34.123.166.158',
  port '3306',
  user 'devuser',
  password 'Inceptez@123'
);

# %%
# %sql
CREATE CONNECTION gcp_mysql_conn_we47
TYPE mysql
OPTIONS (
  host '34.123.166.158',
  port '3306',
  user 'devuser',
  password 'Inceptez@123'
);

# %%
# %sql

CREATE FOREIGN CATALOG cloudsql_foreign_catalog1
USING CONNECTION gcp_mysql_conn_we47;
